# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("D:\MSIS\FML Lab\Part 1\Dataset\mushrooms.csv")

# %%
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment
# 0        p         x           s         n       t    p               f  \
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring
# ...

# %%
dataset=data.sample(frac=1)
dataset.columns = ['target', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor', 'gill-attachment','gill-spacing','gill-size','gill-color','stalk-shape','stalk-root',
                   'stalk-surface-above-ring','stalk-surface-below-ring','stalk-color-above-ring','stalk-color-below-ring','veil-type','veil-color','ring-number','ring-type','spore-print-color','population','habitat']

# %%
# Label Encoding
for label in dataset.columns:
    dataset[label] = LabelEncoder().fit(dataset[label]).transform(dataset[label])

dataset
# Out:
#       target  cap-shape  cap-surface  cap-color  bruises  odor
# 4804       1          2            3          9        0     2  \
# 7042       1          3            3          4        0     8
# 5613       1          5            0          9        0     2
# 2266       0          2            2          8        0     5
# 2916       0          5            3          2        1     5
# ...      ...        ...          ...        ...      ...   ...
# 2694       0          2            0          3        1     5
# 6583       1          2            3          4        0     7
# 3438       0          2            0          2        1     5
# 1426       0          2            2          4        0     5
# 1576       0          5            2          8        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...
# 4804                1             0          0           2  ...  \
# 7042                1             0          1           0  ...
# ...

# %%
X = dataset.drop(columns=['target'], axis=1)
y = dataset['target']

# %%
# Define Train and Test set
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0) # 70% - Train, 20% - Test

# %%
# Create Decision Tree classifier object
model = DecisionTreeClassifier(criterion='entropy',max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator= model, n_estimators= 400, learning_rate=1)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# c:\Users\akash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_base.py:156: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
prediction = metrics.accuracy_score(y_test, y_pred)

# %%
#Accuracy of the Model
print(" Accuracy : ",prediction*100,"%")
# Out:
#  Accuracy :  100.0 %
